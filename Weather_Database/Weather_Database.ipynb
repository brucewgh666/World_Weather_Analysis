# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
coordinates = list(lat_lngs)
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 743

# %%
import requests

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | asau
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | port arthur
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | roma
# Processing Record 7 of Set 1 | shelburne
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | necochea
# Processing Record 11 of Set 1 | cabo san lucas
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | oyama
# Processing Record 14 of Set 1 | esmeraldas
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | faya
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | sabang
# Processing Record 21 of Set 1 | beberibe
# Processing Record 22 of Set 1 | namibe
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 1 | touros
# Processing Record 26 of Set 1 | waingapu
# Processing Record 27 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | yaring
# Processing Record 30 of Set 1 | omsukchan
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | vila franca do campo
# Processing Record 33 of Set 1 | vodnyy
# Processing Record 34 of Set 1 | port lincoln
# Processing Record 35 of Set 1 | salalah
# Processing Record 36 of Set 1 | ous
# Processing Record 37 of Set 1 | saint-joseph
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | vao
# Processing Record 41 of Set 1 | naze
# Processing Record 42 of Set 1 | serenje
# Processing Record 43 of Set 1 | maragogi
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | maldonado
# Processing Record 46 of Set 1 | laguna
# Processing Record 47 of Set 1 | atbasar
# Processing Record 48 of Set 1 | leningradskiy
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | santa cruz
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | kuryk
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | te anau
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | chumikan
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | fomboni
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | bastia
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | srandakan
# Processing Record 18 of Set 2 | berdigestyakh
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | russkiy aktash
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 2 | vagur
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | saldanha
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | port-cartier
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | samarai
# Processing Record 30 of Set 2 | tuensang
# Processing Record 31 of Set 2 | gat
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | elliot lake
# Processing Record 34 of Set 2 | matamoros
# Processing Record 35 of Set 2 | alofi
# Processing Record 36 of Set 2 | bandarawela
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | makokou
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | mokolo
# Processing Record 43 of Set 2 | najran
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | nara
# Processing Record 46 of Set 2 | geilo
# Processing Record 47 of Set 2 | palmer
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | chifeng
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | araouane
# Processing Record 4 of Set 3 | nioro
# Processing Record 5 of Set 3 | duitama
# Processing Record 6 of Set 3 | bac lieu
# Processing Record 7 of Set 3 | xaxim
# Processing Record 8 of Set 3 | vaitape
# Processing Record 9 of Set 3 | sarangani
# Processing Record 10 of Set 3 | vredendal
# Processing Record 11 of Set 3 | brae
# Processing Record 12 of Set 3 | botwood
# Processing Record 13 of Set 3 | aras
# Processing Record 14 of Set 3 | atambua
# Processing Record 15 of Set 3 | luxeuil-les-bains
# Processing Record 16 of Set 3 | san luis
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | port victoria
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | tazovskiy
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | awjilah
# Processing Record 23 of Set 3 | kahului
# Processing Record 24 of Set 3 | cherskiy
# Processing Record 25 of Set 3 | zhigansk
# Processing Record 26 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 3 | guerrero negro
# Processing Record 28 of Set 3 | umm lajj
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | whitehorse
# Processing Record 31 of Set 3 | los llanos de aridane
# Processing Record 32 of Set 3 | listvyagi
# Processing Record 33 of Set 3 | mosquera
# Processing Record 34 of Set 3 | kazachinskoye
# Processing Record 35 of Set 3 | acapulco
# Processing Record 36 of Set 3 | rocha
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 3 | sabancuy
# Processing Record 40 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 3 | yulara
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 3 | beloha
# Processing Record 46 of Set 3 | la palma
# Processing Record 47 of Set 3 | key west
# Processing Record 48 of Set 3 | cahors
# Processing Record 49 of Set 3 | porto velho
# Processing Record 50 of Set 3 | zaysan
# Processing Record 1 of Set 4 | gao
# Processing Record 2 of Set 4 | neiafu
# Processing Record 3 of Set 4 | port blair
# Processing Record 4 of Set 4 | tyrma
# Processing Record 5 of Set 4 | fort nelson
# Processing Record 6 of Set 4 | walvis bay
# Processing Record 7 of Set 4 | vidim
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | cockburn town
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | ahuimanu
# Processing Record 12 of Set 4 | codrington
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | liku
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | mount gambier
# Processing Record 18 of Set 4 | baiyin
# Processing Record 19 of Set 4 | rameshki
# Processing Record 20 of Set 4 | lewistown
# Processing Record 21 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 4 | tarakan
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | seoul
# Processing Record 25 of Set 4 | muros
# Processing Record 26 of Set 4 | havelock
# Processing Record 27 of Set 4 | praia
# Processing Record 28 of Set 4 | baculin
# Processing Record 29 of Set 4 | lemoore
# Processing Record 30 of Set 4 | uddevalla
# Processing Record 31 of Set 4 | kapustin yar
# Processing Record 32 of Set 4 | grand gaube
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | oktyabrskiy
# Processing Record 36 of Set 4 | yumen
# Processing Record 37 of Set 4 | lorengau
# Processing Record 38 of Set 4 | abu samrah
# Processing Record 39 of Set 4 | kemijarvi
# Processing Record 40 of Set 4 | alice springs
# Processing Record 41 of Set 4 | chuy
# Processing Record 42 of Set 4 | makakilo city
# Processing Record 43 of Set 4 | qaanaaq
# Processing Record 44 of Set 4 | cape town
# Processing Record 45 of Set 4 | tilichiki
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | garissa
# Processing Record 48 of Set 4 | impfondo
# Processing Record 49 of Set 4 | lethem
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | oistins
# Processing Record 2 of Set 5 | florianopolis
# Processing Record 3 of Set 5 | nikolskoye
# Processing Record 4 of Set 5 | port moresby
# Processing Record 5 of Set 5 | olafsvik
# Processing Record 6 of Set 5 | matay
# Processing Record 7 of Set 5 | malakal
# Processing Record 8 of Set 5 | arraial do cabo
# Processing Record 9 of Set 5 | lashio
# Processing Record 10 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 5 | juneau
# Processing Record 12 of Set 5 | abu kamal
# Processing Record 13 of Set 5 | jinji
# Processing Record 14 of Set 5 | kingston
# Processing Record 15 of Set 5 | latung
# Processing Record 16 of Set 5 | sekoma
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 5 | cordoba
# Processing Record 21 of Set 5 | birin
# Processing Record 22 of Set 5 | isangel
# Processing Record 23 of Set 5 | bontang
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | buala
# Processing Record 26 of Set 5 | weligama
# Processing Record 27 of Set 5 | otjimbingwe
# Processing Record 28 of Set 5 | lebu
# Processing Record 29 of Set 5 | sakaiminato
# Processing Record 30 of Set 5 | xai-xai
# Processing Record 31 of Set 5 | saint cloud
# Processing Record 32 of Set 5 | mocoa
# Processing Record 33 of Set 5 | balakhninskiy
# Processing Record 34 of Set 5 | yeppoon
# Processing Record 35 of Set 5 | ballina
# Processing Record 36 of Set 5 | roshchino
# Processing Record 37 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 5 | huilong
# Processing Record 39 of Set 5 | gigmoto
# Processing Record 40 of Set 5 | sakakah
# Processing Record 41 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 5 | kavaratti
# Processing Record 43 of Set 5 | othaya
# Processing Record 44 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 5 | buraydah
# Processing Record 46 of Set 5 | northam
# Processing Record 47 of Set 5 | sitka
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 50 of Set 5 | okha
# Processing Record 1 of Set 6 | tchibanga
# Processing Record 2 of Set 6 | san cristobal
# Processing Record 3 of Set 6 | sobolevo
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | lagoa
# Processing Record 6 of Set 6 | piranhas
# Processing Record 7 of Set 6 | oussouye
# Processing Record 8 of Set 6 | larsnes
# Processing Record 9 of Set 6 | bathsheba
# Processing Record 10 of Set 6 | grindsted
# Processing Record 11 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 6 | atar
# Processing Record 13 of Set 6 | hurghada
# Processing Record 14 of Set 6 | narasannapeta
# Processing Record 15 of Set 6 | taywarah
# Processing Record 16 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 17 of Set 6 | shimoda
# Processing Record 18 of Set 6 | santa cruz de la palma
# Processing Record 19 of Set 6 | luau
# Processing Record 20 of Set 6 | saint-augustin
# Processing Record 21 of Set 6 | vardo
# Processing Record 22 of Set 6 | chilca
# Processing Record 23 of Set 6 | bose
# Processing Record 24 of Set 6 | san carlos
# Processing Record 25 of Set 6 | amazar
# Processing Record 26 of Set 6 | tczew
# Processing Record 27 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | ancud
# Processing Record 29 of Set 6 | bandarban
# Processing Record 30 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 6 | aragarcas
# Processing Record 32 of Set 6 | ust-kut
# Processing Record 33 of Set 6 | gogrial
# Processing Record 34 of Set 6 | portland
# Processing Record 35 of Set 6 | san felipe
# Processing Record 36 of Set 6 | saint-georges
# Processing Record 37 of Set 6 | ostrovnoy
# Processing Record 38 of Set 6 | saint george
# Processing Record 39 of Set 6 | nouadhibou
# Processing Record 40 of Set 6 | alta floresta
# Processing Record 41 of Set 6 | pascagoula
# Processing Record 42 of Set 6 | dunedin
# Processing Record 43 of Set 6 | berlevag
# Processing Record 44 of Set 6 | norman wells
# Processing Record 45 of Set 6 | farafangana
# Processing Record 46 of Set 6 | khatanga
# Processing Record 47 of Set 6 | aklavik
# Processing Record 48 of Set 6 | sept-iles
# Processing Record 49 of Set 6 | luderitz
# Processing Record 50 of Set 6 | carballo
# Processing Record 1 of Set 7 | saskylakh
# Processing Record 2 of Set 7 | kadhan
# Processing Record 3 of Set 7 | mackay
# Processing Record 4 of Set 7 | fez
# Processing Record 5 of Set 7 | borisoglebskiy
# Processing Record 6 of Set 7 | ilulissat
# Processing Record 7 of Set 7 | geraldton
# Processing Record 8 of Set 7 | san patricio
# Processing Record 9 of Set 7 | okhotsk
# Processing Record 10 of Set 7 | panaba
# Processing Record 11 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 12 of Set 7 | port keats
# Processing Record 13 of Set 7 | idar
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | saint-leu
# Processing Record 16 of Set 7 | karakol
# Processing Record 17 of Set 7 | kailua
# Processing Record 18 of Set 7 | port elizabeth
# Processing Record 19 of Set 7 | almaznyy
# Processing Record 20 of Set 7 | talnakh
# Processing Record 21 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 7 | talcahuano
# Processing Record 23 of Set 7 | bowen
# Processing Record 24 of Set 7 | san vicente de canete
# Processing Record 25 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 7 | jaru
# Processing Record 27 of Set 7 | itaituba
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | rajbiraj
# Processing Record 30 of Set 7 | chokurdakh
# Processing Record 31 of Set 7 | fukue
# Processing Record 32 of Set 7 | mpophomeni
# Processing Record 33 of Set 7 | alexandria
# Processing Record 34 of Set 7 | zhuhai
# Processing Record 35 of Set 7 | yambio
# Processing Record 36 of Set 7 | balkanabat
# Processing Record 37 of Set 7 | altamont
# Processing Record 38 of Set 7 | santiago del estero
# Processing Record 39 of Set 7 | talaya
# Processing Record 40 of Set 7 | orlik
# Processing Record 41 of Set 7 | ayan
# Processing Record 42 of Set 7 | kushima
# Processing Record 43 of Set 7 | emilio carranza
# Processing Record 44 of Set 7 | boyolangu
# Processing Record 45 of Set 7 | moose factory
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | severo-yeniseyskiy
# Processing Record 48 of Set 7 | sechura
# Processing Record 49 of Set 7 | kirakira
# Processing Record 50 of Set 7 | charters towers
# Processing Record 1 of Set 8 | pinheiro machado
# Processing Record 2 of Set 8 | lunsar
# Processing Record 3 of Set 8 | springfield
# Processing Record 4 of Set 8 | klaksvik
# Processing Record 5 of Set 8 | puerto escondido
# Processing Record 6 of Set 8 | coquimbo
# Processing Record 7 of Set 8 | hambantota
# Processing Record 8 of Set 8 | brazzaville
# Processing Record 9 of Set 8 | pitimbu
# Processing Record 10 of Set 8 | mitsamiouli
# Processing Record 11 of Set 8 | mnogovershinnyy
# Processing Record 12 of Set 8 | khani
# Processing Record 13 of Set 8 | bethel
# Processing Record 14 of Set 8 | lasa
# Processing Record 15 of Set 8 | johnson city
# Processing Record 16 of Set 8 | margate
# Processing Record 17 of Set 8 | ler
# Processing Record 18 of Set 8 | matinhos
# Processing Record 19 of Set 8 | leshukonskoye
# Processing Record 20 of Set 8 | vestmannaeyjar
# Processing Record 21 of Set 8 | steamboat springs
# Processing Record 22 of Set 8 | coihaique
# Processing Record 23 of Set 8 | kamenka
# Processing Record 24 of Set 8 | idrinskoye
# Processing Record 25 of Set 8 | jaque
# Processing Record 26 of Set 8 | bambanglipuro
# Processing Record 27 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 28 of Set 8 | half moon bay
# Processing Record 29 of Set 8 | tres lagoas
# Processing Record 30 of Set 8 | loa janan
# Processing Record 31 of Set 8 | saravan
# Processing Record 32 of Set 8 | matagami
# Processing Record 33 of Set 8 | san quintin
# Processing Record 34 of Set 8 | tazmalt
# Processing Record 35 of Set 8 | melfi
# Processing Record 36 of Set 8 | sola
# Processing Record 37 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 8 | bayburt
# Processing Record 39 of Set 8 | praia da vitoria
# Processing Record 40 of Set 8 | lavrentiya
# Processing Record 41 of Set 8 | rio gallegos
# Processing Record 42 of Set 8 | sompeta
# Processing Record 43 of Set 8 | arlit
# Processing Record 44 of Set 8 | padang
# Processing Record 45 of Set 8 | isabela
# Processing Record 46 of Set 8 | komsomolskiy
# Processing Record 47 of Set 8 | souillac
# Processing Record 48 of Set 8 | takoradi
# Processing Record 49 of Set 8 | lamar
# Processing Record 50 of Set 8 | goma
# Processing Record 1 of Set 9 | sabha
# Processing Record 2 of Set 9 | biltine
# Processing Record 3 of Set 9 | abasolo
# Processing Record 4 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 9 | kruisfontein
# Processing Record 6 of Set 9 | wamba
# Processing Record 7 of Set 9 | lieksa
# Processing Record 8 of Set 9 | andenes
# Processing Record 9 of Set 9 | ano mera
# Processing Record 10 of Set 9 | shajapur
# Processing Record 11 of Set 9 | ozinki
# Processing Record 12 of Set 9 | dhidhdhoo
# Processing Record 13 of Set 9 | mustasaari
# Processing Record 14 of Set 9 | bobo dioulasso
# Processing Record 15 of Set 9 | doha
# Processing Record 16 of Set 9 | puerto ayacucho
# Processing Record 17 of Set 9 | kyra
# Processing Record 18 of Set 9 | kant
# Processing Record 19 of Set 9 | pittsburg
# Processing Record 20 of Set 9 | vanderhoof
# Processing Record 21 of Set 9 | iroquois falls
# Processing Record 22 of Set 9 | aljezur
# Processing Record 23 of Set 9 | itoman
# Processing Record 24 of Set 9 | hualmay
# Processing Record 25 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 26 of Set 9 | shahrud
# Processing Record 27 of Set 9 | tabou
# Processing Record 28 of Set 9 | shu
# Processing Record 29 of Set 9 | itaguai
# Processing Record 30 of Set 9 | manicore
# Processing Record 31 of Set 9 | natal
# Processing Record 32 of Set 9 | taoudenni
# Processing Record 33 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 9 | pirmasens
# Processing Record 35 of Set 9 | saint anthony
# Processing Record 36 of Set 9 | tocopilla
# Processing Record 37 of Set 9 | xichang
# Processing Record 38 of Set 9 | high level
# Processing Record 39 of Set 9 | viedma
# Processing Record 40 of Set 9 | narsaq
# Processing Record 41 of Set 9 | carutapera
# Processing Record 42 of Set 9 | itapage
# Processing Record 43 of Set 9 | antofagasta
# Processing Record 44 of Set 9 | scarborough
# Processing Record 45 of Set 9 | ritchie
# Processing Record 46 of Set 9 | millau
# Processing Record 47 of Set 9 | kurilsk
# Processing Record 48 of Set 9 | faanui
# Processing Record 49 of Set 9 | axim
# Processing Record 50 of Set 9 | bayir
# Processing Record 1 of Set 10 | lithakia
# Processing Record 2 of Set 10 | darhan
# Processing Record 3 of Set 10 | kulhudhuffushi
# Processing Record 4 of Set 10 | sundargarh
# Processing Record 5 of Set 10 | liuhe
# Processing Record 6 of Set 10 | synya
# Processing Record 7 of Set 10 | tamale
# Processing Record 8 of Set 10 | mattru
# Processing Record 9 of Set 10 | maceio
# Processing Record 10 of Set 10 | mabaruma
# Processing Record 11 of Set 10 | nome
# Processing Record 12 of Set 10 | salinopolis
# Processing Record 13 of Set 10 | kaitangata
# Processing Record 14 of Set 10 | ulaangom
# Processing Record 15 of Set 10 | monastyrshchina
# Processing Record 16 of Set 10 | prince george
# Processing Record 17 of Set 10 | grivenskaya
# Processing Record 18 of Set 10 | dicabisagan
# Processing Record 19 of Set 10 | jablah
# Processing Record 20 of Set 10 | srednekolymsk
# Processing Record 21 of Set 10 | nikki
# Processing Record 22 of Set 10 | oriximina
# Processing Record 23 of Set 10 | gamba
# Processing Record 24 of Set 10 | port hedland
# Processing Record 25 of Set 10 | koltubanovskiy
# Processing Record 26 of Set 10 | iquique
# Processing Record 27 of Set 10 | tingo maria
# Processing Record 28 of Set 10 | russell
# Processing Record 29 of Set 10 | mendoza
# Processing Record 30 of Set 10 | merauke
# Processing Record 31 of Set 10 | karpathos
# Processing Record 32 of Set 10 | chapais
# Processing Record 33 of Set 10 | fairbanks
# Processing Record 34 of Set 10 | hobyo
# Processing Record 35 of Set 10 | flinders
# Processing Record 36 of Set 10 | powell
# Processing Record 37 of Set 10 | beya
# Processing Record 38 of Set 10 | pekan
# Processing Record 39 of Set 10 | port hardy
# Processing Record 40 of Set 10 | mount isa
# Processing Record 41 of Set 10 | qaqortoq
# Processing Record 42 of Set 10 | hofn
# Processing Record 43 of Set 10 | grindavik
# Processing Record 44 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 45 of Set 10 | rawson
# Processing Record 46 of Set 10 | tawang
# Processing Record 47 of Set 10 | avera
# Processing Record 48 of Set 10 | sioux lookout
# Processing Record 49 of Set 10 | dera bugti
# Processing Record 50 of Set 10 | satoraljaujhely
# Processing Record 1 of Set 11 | quatre cocos
# Processing Record 2 of Set 11 | sao filipe
# Processing Record 3 of Set 11 | pangody
# Processing Record 4 of Set 11 | calama
# Processing Record 5 of Set 11 | lang son
# Processing Record 6 of Set 11 | vila velha
# Processing Record 7 of Set 11 | yaan
# Processing Record 8 of Set 11 | horta
# Processing Record 9 of Set 11 | yar-sale
# Processing Record 10 of Set 11 | saint-pierre
# Processing Record 11 of Set 11 | lae
# Processing Record 12 of Set 11 | lulea
# Processing Record 13 of Set 11 | morgan city
# Processing Record 14 of Set 11 | gazli
# Processing Record 15 of Set 11 | katsuura
# Processing Record 16 of Set 11 | mabay
# Processing Record 17 of Set 11 | shenzhen
# Processing Record 18 of Set 11 | ariogala
# Processing Record 19 of Set 11 | banjar
# Processing Record 20 of Set 11 | miandoab
# Processing Record 21 of Set 11 | severo-kurilsk
# Processing Record 22 of Set 11 | boa vista
# Processing Record 23 of Set 11 | praya
# Processing Record 24 of Set 11 | camacari
# Processing Record 25 of Set 11 | batagay-alyta
# Processing Record 26 of Set 11 | puteyets
# Processing Record 27 of Set 11 | ogdensburg
# Processing Record 28 of Set 11 | xadani
# City not found. Skipping...
# Processing Record 29 of Set 11 | kuah
# Processing Record 30 of Set 11 | klyuchi
# Processing Record 31 of Set 11 | veraval
# Processing Record 32 of Set 11 | krutikha
# Processing Record 33 of Set 11 | lincoln
# Processing Record 34 of Set 11 | riyadh
# Processing Record 35 of Set 11 | ahipara
# Processing Record 36 of Set 11 | port hawkesbury
# Processing Record 37 of Set 11 | artesia
# Processing Record 38 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 11 | haverfordwest
# Processing Record 40 of Set 11 | karratha
# Processing Record 41 of Set 11 | sao joao da barra
# Processing Record 42 of Set 11 | gambela
# Processing Record 43 of Set 11 | jacarei
# Processing Record 44 of Set 11 | kyakhta
# Processing Record 45 of Set 11 | toribio
# Processing Record 46 of Set 11 | acarau
# Processing Record 47 of Set 11 | englehart
# Processing Record 48 of Set 11 | ormara
# Processing Record 49 of Set 11 | tigil
# Processing Record 50 of Set 11 | yen bai
# Processing Record 1 of Set 12 | barcelos
# Processing Record 2 of Set 12 | dubasari
# Processing Record 3 of Set 12 | aquiraz
# Processing Record 4 of Set 12 | kirkwood
# Processing Record 5 of Set 12 | carauari
# Processing Record 6 of Set 12 | kopavogur
# Processing Record 7 of Set 12 | jizan
# Processing Record 8 of Set 12 | chisindia
# Processing Record 9 of Set 12 | baruun-urt
# Processing Record 10 of Set 12 | novobiryusinskiy
# Processing Record 11 of Set 12 | pangai
# Processing Record 12 of Set 12 | la rioja
# Processing Record 13 of Set 12 | bubaque
# Processing Record 14 of Set 12 | indianola
# Processing Record 15 of Set 12 | adrar
# Processing Record 16 of Set 12 | mecca
# Processing Record 17 of Set 12 | san policarpo
# Processing Record 18 of Set 12 | pallisa
# Processing Record 19 of Set 12 | prainha
# Processing Record 20 of Set 12 | rio bueno
# Processing Record 21 of Set 12 | deep river
# Processing Record 22 of Set 12 | maimon
# City not found. Skipping...
# Processing Record 23 of Set 12 | mandurah
# Processing Record 24 of Set 12 | anadyr
# Processing Record 25 of Set 12 | kisaran
# Processing Record 26 of Set 12 | ziro
# Processing Record 27 of Set 12 | centralia
# Processing Record 28 of Set 12 | sauda
# Processing Record 29 of Set 12 | san carlos del zulia
# Processing Record 30 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 31 of Set 12 | opuwo
# Processing Record 32 of Set 12 | ixtapa
# Processing Record 33 of Set 12 | bulgan
# Processing Record 34 of Set 12 | lokachi
# Processing Record 35 of Set 12 | eslov
# Processing Record 36 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 12 | egvekinot
# Processing Record 38 of Set 12 | nalundan
# Processing Record 39 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 12 | sorland
# Processing Record 41 of Set 12 | deputatskiy
# Processing Record 42 of Set 12 | sao sebastiao
# Processing Record 43 of Set 12 | sawakin
# Processing Record 44 of Set 12 | murree
# Processing Record 45 of Set 12 | denpasar
# Processing Record 46 of Set 12 | algiers
# Processing Record 47 of Set 12 | hanover
# Processing Record 48 of Set 12 | gazanjyk
# Processing Record 49 of Set 12 | nobres
# Processing Record 50 of Set 12 | palana
# Processing Record 1 of Set 13 | mezen
# Processing Record 2 of Set 13 | tshane
# Processing Record 3 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 13 | mojokerto
# Processing Record 6 of Set 13 | gijon
# Processing Record 7 of Set 13 | abu zabad
# Processing Record 8 of Set 13 | labuhan
# Processing Record 9 of Set 13 | amapa
# Processing Record 10 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 13 | abha
# Processing Record 12 of Set 13 | yarmouth
# Processing Record 13 of Set 13 | hun
# Processing Record 14 of Set 13 | qui nhon
# Processing Record 15 of Set 13 | qasigiannguit
# Processing Record 16 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 13 | cabedelo
# Processing Record 18 of Set 13 | ust-kuyga
# Processing Record 19 of Set 13 | amnat charoen
# Processing Record 20 of Set 13 | mayo
# Processing Record 21 of Set 13 | hamilton
# Processing Record 22 of Set 13 | flin flon
# Processing Record 23 of Set 13 | constitucion
# Processing Record 24 of Set 13 | yegorlykskaya
# Processing Record 25 of Set 13 | cayenne
# Processing Record 26 of Set 13 | inhambane
# Processing Record 27 of Set 13 | tobermory
# Processing Record 28 of Set 13 | dawson creek
# Processing Record 29 of Set 13 | tadepallegudem
# Processing Record 30 of Set 13 | bima
# Processing Record 31 of Set 13 | sunbury
# Processing Record 32 of Set 13 | bonavista
# Processing Record 33 of Set 13 | seydi
# Processing Record 34 of Set 13 | biak
# Processing Record 35 of Set 13 | luunja
# Processing Record 36 of Set 13 | kununurra
# Processing Record 37 of Set 13 | basse-pointe
# Processing Record 38 of Set 13 | asyut
# Processing Record 39 of Set 13 | cape coast
# Processing Record 40 of Set 13 | kikinda
# Processing Record 41 of Set 13 | znamenskoye
# Processing Record 42 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 13 | mlimba
# Processing Record 44 of Set 13 | kieta
# Processing Record 45 of Set 13 | sisimiut
# Processing Record 46 of Set 13 | gainesville
# Processing Record 47 of Set 13 | marsabit
# Processing Record 48 of Set 13 | sarh
# Processing Record 49 of Set 13 | coracora
# Processing Record 50 of Set 13 | ternate
# Processing Record 1 of Set 14 | korla
# Processing Record 2 of Set 14 | laguna de perlas
# Processing Record 3 of Set 14 | namatanai
# Processing Record 4 of Set 14 | togur
# Processing Record 5 of Set 14 | anupgarh
# Processing Record 6 of Set 14 | aykhal
# Processing Record 7 of Set 14 | henties bay
# Processing Record 8 of Set 14 | eydhafushi
# Processing Record 9 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 14 | aykino
# Processing Record 11 of Set 14 | patacamaya
# Processing Record 12 of Set 14 | galle
# Processing Record 13 of Set 14 | smolenka
# Processing Record 14 of Set 14 | roebourne
# Processing Record 15 of Set 14 | lata
# Processing Record 16 of Set 14 | bekhtery
# Processing Record 17 of Set 14 | kangaatsiaq
# Processing Record 18 of Set 14 | husavik
# Processing Record 19 of Set 14 | trairi
# Processing Record 20 of Set 14 | talara
# Processing Record 21 of Set 14 | ndele
# Processing Record 22 of Set 14 | comodoro rivadavia
# Processing Record 23 of Set 14 | le mars
# Processing Record 24 of Set 14 | ananas
# Processing Record 25 of Set 14 | nemuro
# Processing Record 26 of Set 14 | channarayapatna
# Processing Record 27 of Set 14 | rovaniemi
# Processing Record 28 of Set 14 | kandrian
# Processing Record 29 of Set 14 | tibati
# Processing Record 30 of Set 14 | matara
# Processing Record 31 of Set 14 | preobrazheniye
# Processing Record 32 of Set 14 | eureka
# Processing Record 33 of Set 14 | havoysund
# Processing Record 34 of Set 14 | kutahya
# Processing Record 35 of Set 14 | ngunguru
# Processing Record 36 of Set 14 | inuvik
# Processing Record 37 of Set 14 | vanimo
# Processing Record 38 of Set 14 | camacha
# Processing Record 39 of Set 14 | kalemie
# Processing Record 40 of Set 14 | diffa
# Processing Record 41 of Set 14 | pacific grove
# Processing Record 42 of Set 14 | ziarat
# Processing Record 43 of Set 14 | pochutla
# Processing Record 44 of Set 14 | morant bay
# Processing Record 45 of Set 14 | wajir
# Processing Record 46 of Set 14 | yverdon
# City not found. Skipping...
# Processing Record 47 of Set 14 | nsanje
# Processing Record 48 of Set 14 | upata
# Processing Record 49 of Set 14 | yantal
# Processing Record 50 of Set 14 | erdenet
# Processing Record 1 of Set 15 | wajima
# Processing Record 2 of Set 15 | neya
# Processing Record 3 of Set 15 | altay
# Processing Record 4 of Set 15 | manga
# Processing Record 5 of Set 15 | askiz
# Processing Record 6 of Set 15 | maun
# Processing Record 7 of Set 15 | moron
# Processing Record 8 of Set 15 | ilave
# Processing Record 9 of Set 15 | luba
# Processing Record 10 of Set 15 | ketchikan
# Processing Record 11 of Set 15 | san juan
# Processing Record 12 of Set 15 | obihiro
# Processing Record 13 of Set 15 | bandarbeyla
# Processing Record 14 of Set 15 | dovers
# Processing Record 15 of Set 15 | mushie
# Processing Record 16 of Set 15 | tura
# Processing Record 17 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 15 | jaleswar
# Processing Record 19 of Set 15 | ranot
# Processing Record 20 of Set 15 | nampa
# Processing Record 21 of Set 15 | aburi
# Processing Record 22 of Set 15 | oakdale
# Processing Record 23 of Set 15 | jalu
# Processing Record 24 of Set 15 | saurimo
# Processing Record 25 of Set 15 | bilibino
# Processing Record 26 of Set 15 | shar
# Processing Record 27 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 28 of Set 15 | male
# Processing Record 29 of Set 15 | uruguaiana
# Processing Record 30 of Set 15 | mouzouras
# Processing Record 31 of Set 15 | paulo ramos
# Processing Record 32 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 33 of Set 15 | zhezkazgan
# Processing Record 34 of Set 15 | bakaly
# Processing Record 35 of Set 15 | wajid
# Processing Record 36 of Set 15 | poum
# Processing Record 37 of Set 15 | colinas
# Processing Record 38 of Set 15 | ibra
# Processing Record 39 of Set 15 | sapernoye
# Processing Record 40 of Set 15 | lucapa
# Processing Record 41 of Set 15 | soligalich
# Processing Record 42 of Set 15 | hvide sande
# Processing Record 43 of Set 15 | college
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Asau      RO  46.4333   26.4000     39.40        85         100
# 1       Jamestown      US  42.0970  -79.2353     47.84        71           1
# 2          Albany      US  42.6001  -73.9662     39.85        73          84
# 3     Port Arthur      CN  38.8000  121.2667     46.90        60         100
# 4            Roma      US  43.2128  -75.4557     40.86        79          90
# 5       Shelburne      CA  44.0787  -80.2041     35.49        92         100
# 6       Carnarvon      AU -24.8667  113.6333     69.87        78          40
# 7        Bengkulu      ID  -3.8004  102.2655     74.44        94         100
# 8        Necochea      AR -38.5473  -58.7368     67.03        89          97
# 9  Cabo San Lucas      MX  22.8909 -109.9124     80.51        60          95
#
#    Wind Speed Current Description
# 0        4.03          light rain
# 1        3.44           clear sky
# 2        2.82       broken clouds
# 3        6.44     overcast clouds
# 4        5.75     overcast clouds
# 5        3.06     overcast clouds
# 6       14.97    scattered clouds
# 7        4.21          light rain
# 8       15.84          light rain
# 9        7.00     overcast clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
